# %%
import pandas as pd

dataset = pd.read_csv('vehicle_price_prediction.csv')

# %%
dataset
# Out:
#              make       model  year  mileage  engine_hp transmission  \
# 0      Volkswagen       Jetta  2016   183903        173       Manual
# 1           Lexus          RX  2010   236643        352       Manual
# 2          Subaru   Crosstrek  2016   103199        188    Automatic
# 3        Cadillac       Lyriq  2016   118889        338       Manual
# 4          Toyota  Highlander  2018   204170        196       Manual
# ...           ...         ...   ...      ...        ...          ...
# 65530         Kia    Sportage  2014   151413         96       Manual
# 65531         Kia     Sorento  2010   179660        115       Manual
# 65532       Tesla     Model 3  2019    37521        372    Automatic
# 65533       Dodge     Charger  2020    51828        240       Manual
# 65534        Jeep     Compass  2015   195035        217    Automatic
#
#       fuel_type drivetrain body_type exterior_color interior_color  \
# 0      Electric        RWD     Sedan           Blue          Brown
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   make              65535 non-null  object
#  1   model             65535 non-null  object
#  2   year              65535 non-null  int64
#  3   mileage           65535 non-null  int64
#  4   engine_hp         65535 non-null  int64
#  5   transmission      65535 non-null  object
#  6   fuel_type         65535 non-null  object
#  7   drivetrain        65535 non-null  object
#  8   body_type         65535 non-null  object
#  9   exterior_color    65535 non-null  object
#  10  interior_color    65535 non-null  object
#  11  owner_count       65535 non-null  int64
#  12  accident_history  16440 non-null  object
#  13  seller_type       65535 non-null  object
#  14  condition         65535 non-null  object
#  15  trim              65535 non-null  object
# ...
